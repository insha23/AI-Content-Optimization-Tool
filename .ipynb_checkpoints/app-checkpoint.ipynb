# %% [markdown]
# # AI Content Optimization Tool
# ## Import Libraries
# ## Load Input Text
# ## Text Preprocessing
# ## Readability Analysis
# ## Keyword Analysis
# ## Content Metrics
# ## Suggestion Engine
# ## Visualization
# ## Heading Detection
# ## Final Function
# ## Output

# %%
import re
import nltk
import textstat
import pandas as pd
import matplotlib.pyplot as plt

from collections import Counter
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

# %%
try:
    with open("sample_text.txt", "r", encoding="utf-8") as file:
        text = file.read()
    print("Text loaded successfully.\n")
    print(text[:300])   # preview first 300 characters
except FileNotFoundError:
    print("sample_text.txt not found. Please keep it in the same folder as the notebook.")

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

sentences = sent_tokenize(text)
words = word_tokenize(text.lower())

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalnum() and word not in stop_words]

print("Total sentences:", len(sentences))
print("Total filtered words:", len(filtered_words))
print("Sample filtered words:", filtered_words[:15])

# %%
import textstat

readability_score = textstat.flesch_reading_ease(text)
grade_level = textstat.flesch_kincaid_grade(text)

print("Readability Score:", round(readability_score, 2))
print("Grade Level:", round(grade_level, 2))
# Out:
# Readability Score: -0.03391393442618096
# Grade Level: 17.05258196721311

# %%
target_keyword = "optimization"
keyword_count = text.lower().count(target_keyword.lower())
print(f"Keyword '{target_keyword}' appears {keyword_count} times.")
# Out:
# Keyword 'optimization' appears 2 times.

# %%
word_freq = Counter(filtered_words)
top_words = word_freq.most_common(10)

print("Top 10 Keywords:")
for word, count in top_words:
    print(word, ":", count)
# Out:
# Top 10 Keywords:
# content : 4
# generative : 3
# engine : 2
# optimization : 2
# search : 2
# engines : 2
# information : 2
# factors : 2
# geo : 2
# process : 1

# %%
num_sentences = len(sentences)
num_words = len(filtered_words)
avg_sentence_length = num_words / num_sentences if num_sentences > 0 else 0

print("Number of Sentences:", num_sentences)
print("Number of Words:", num_words)
print("Average Sentence Length:", round(avg_sentence_length, 2))
# Out:
# Number of Sentences: 4
# Number of Words: 46
# Average Sentence Length: 11.5

# %%
suggestions = []

if readability_score < 60:
    suggestions.append("Improve readability by using shorter and simpler sentences.")

if keyword_count < 2:
    suggestions.append(f"Increase the usage of the keyword '{target_keyword}' naturally in the content.")

if avg_sentence_length > 20:
    suggestions.append("Reduce average sentence length for better clarity.")

if num_words < 150:
    suggestions.append("Content is short. Add more useful information to improve discoverability.")

if len(top_words) > 0:
    suggestions.append("Use important repeated terms in headings or subheadings for better structure.")

# %%
print("\nSuggestions:")
for i, suggestion in enumerate(suggestions, 1):
    print(f"{i}. {suggestion}")
# Out:
# Suggestions:
# 1. Improve readability by using shorter and simpler sentences.
# 2. Content is short. Add more useful information to improve discoverability.
# 3. Use important repeated terms in headings or subheadings for better structure.

# %%
results = {
    "Metric": [
        "Readability Score",
        "Grade Level",
        "Keyword Count",
        "Total Sentences",
        "Total Words",
        "Average Sentence Length"
    ],
    "Value": [
        readability_score,
        grade_level,
        keyword_count,
        num_sentences,
        num_words,
        round(avg_sentence_length, 2)
    ]
}

df = pd.DataFrame(results)
df
# Out:
#                     Metric      Value
# 0        Readability Score  -0.033914
# 1              Grade Level  17.052582
# 2            Keyword Count   2.000000
# 3          Total Sentences   4.000000
# 4              Total Words  46.000000
# 5  Average Sentence Length  11.500000

# %%
top_df = pd.DataFrame(top_words, columns=["Word", "Count"])

plt.figure(figsize=(10,5))
plt.bar(top_df["Word"], top_df["Count"])
plt.title("Top Repeated Words")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# If text has headings, you can detect simple heading lines.

# %%
lines = text.split('\n')
possible_headings = [line for line in lines if len(line.split()) < 8 and line.isupper()]

print("Possible Headings:")
for h in possible_headings:
    print("-", h)
# Out:
# Possible Headings:
# - GENERATIVE ENGINE OPTIMIZATION
# - WHY CONTENT STRUCTURE MATTERS
# - KEY FACTORS IN GEO
# - BENEFITS OF GEO

# %%
def analyze_content(text, target_keyword):
    sentences = sent_tokenize(text)
    words = word_tokenize(text.lower())

    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.isalnum() and word not in stop_words]

    readability_score = textstat.flesch_reading_ease(text)
    grade_level = textstat.flesch_kincaid_grade(text)
    keyword_count = text.lower().count(target_keyword.lower())
    num_sentences = len(sentences)
    num_words = len(filtered_words)
    avg_sentence_length = num_words / num_sentences if num_sentences > 0 else 0

    word_freq = Counter(filtered_words)
    top_words = word_freq.most_common(10)

    suggestions = []

    if readability_score < 60:
        suggestions.append("Improve readability by using shorter and simpler sentences.")
    if keyword_count < 2:
        suggestions.append(f"Increase the usage of the keyword '{target_keyword}' naturally in the content.")
    if avg_sentence_length > 20:
        suggestions.append("Reduce average sentence length for better clarity.")
    if num_words < 150:
        suggestions.append("Content is short. Add more useful information to improve discoverability.")
    if len(top_words) > 0:
        suggestions.append("Use important repeated terms in headings or subheadings for better structure.")

    return {
        "readability_score": readability_score,
        "grade_level": grade_level,
        "keyword_count": keyword_count,
        "num_sentences": num_sentences,
        "num_words": num_words,
        "avg_sentence_length": avg_sentence_length,
        "top_words": top_words,
        "suggestions": suggestions
    }

# %%
result = analyze_content(text, "optimization")
result
# Out:
# {'readability_score': -0.03391393442618096,
#  'grade_level': 17.05258196721311,
#  'keyword_count': 2,
#  'num_sentences': 4,
#  'num_words': 46,
#  'avg_sentence_length': 11.5,
#  'top_words': [('content', 4),
#   ('generative', 3),
#   ('engine', 2),
#   ('optimization', 2),
#   ('search', 2),
#   ('engines', 2),
#   ('information', 2),
#   ('factors', 2),
#   ('geo', 2),
#   ('process', 1)],
#  'suggestions': ['Improve readability by using shorter and simpler sentences.',
#   'Content is short. Add more useful information to improve discoverability.',
#   'Use important repeated terms in headings or subheadings for better structure.']}
